# %% [markdown]
# # Chapter 2, exercise 1, Ramen analysis

# %% [markdown]
# ## Import required modules

# %%
import pandas as pd

# %% [markdown]
# # Tasks list

# %%
# Task 01 Read the data from the CSV file into a DataFrame.
ramen_data = pd.read_csv("ramen-ratings.csv")

# %%
# Task 02 Display first 5 rows of data.
ramen_data.head()
# Out:
#             Brand                                            Variety Style  \
# 0       New Touch                          T's Restaurant Tantanmen    Cup
# 1        Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack
# 2          Nissin                      Cup Noodles Chicken Vegetable   Cup
# 3         Wei Lih                      GGE Ramen Snack Tomato Flavor  Pack
# 4  Ching's Secret                                    Singapore Curry  Pack
#
#   Country  Stars
# 0   Japan   3.75
# 1  Taiwan   1.00
# 2     USA   2.25
# 3  Taiwan   2.75
# 4   India   3.75

# %%
# Task 03 Display last 5 rows of data.
ramen_data.tail()
# Out:
#          Brand                                            Variety Style  \
# 2572     Vifon  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl
# 2573   Wai Wai                     Oriental Style Instant Noodles  Pack
# 2574   Wai Wai                                     Tom Yum Shrimp  Pack
# 2575   Wai Wai                               Tom Yum Chili Flavor  Pack
# 2576  Westbrae                                         Miso Ramen  Pack
#
#        Country  Stars
# 2572   Vietnam    3.5
# 2573  Thailand    1.0
# 2574  Thailand    2.0
# 2575  Thailand    2.0
# 2576       USA    0.5

# %%
# Task 04 Display statistical information for the numeric columns using the describe() method.
ramen_data.describe()
# Out:
#              Stars
# count  2577.000000
# mean      3.654676
# std       1.015331
# min       0.000000
# 25%       3.250000
# 50%       3.750000
# 75%       4.250000
# max       5.000000

# %%
# Task 05 Display the number of unique values for each column.
ramen_data.nunique()
# Out:
# Brand       355
# Variety    2410
# Style         7
# Country      38
# Stars        42
# dtype: int64

# %%
# Task 06 Display only rows for the country Vietnam.
ramen_data.query('Country == "Vietnam"')
# Out:
#               Brand                                            Variety Style  \
# 18         Binh Tay                                         Mi Hai Cua  Pack
# 52    Uni-President                                    Mushroom Flavor  Pack
# 143        Mum Ngon                                   Lau Tom Chua Cay  Pack
# 224           Vifon  Viet Cuisine Bun Rieu Cua Sour Crab Soup Insta...  Bowl
# 365         Acecook                             Oh! Ricey Pork Flavour  Pack
# ...             ...                                                ...   ...
# 2486       Binh Tay                                   Mi Chay Mushroom  Pack
# 2535        Ve Wong                             Kung-Fu Chicken Flavor  Pack
# 2570        Ve Wong                                      Mushroom Pork  Pack
# 2571          Vifon                                           Nam Vang  Pack
# 2572          Vifon  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl
#
#       Country  Stars
# 18    Vietnam   4.00
# ...

# %%
# Task 07 Display the Brand and Style columns.
ramen_data[['Brand', 'Style']]
# Out:
#                Brand Style
# 0          New Touch   Cup
# 1           Just Way  Pack
# 2             Nissin   Cup
# 3            Wei Lih  Pack
# 4     Ching's Secret  Pack
# ...              ...   ...
# 2572           Vifon  Bowl
# 2573         Wai Wai  Pack
# 2574         Wai Wai  Pack
# 2575         Wai Wai  Pack
# 2576        Westbrae  Pack
#
# [2577 rows x 2 columns]

# %%
# Task 08a Display only the Country column, using "." dot notation.
ramen_data.Country
# Out:
# 0          Japan
# 1         Taiwan
# 2            USA
# 3         Taiwan
# 4          India
#           ...
# 2572     Vietnam
# 2573    Thailand
# 2574    Thailand
# 2575    Thailand
# 2576         USA
# Name: Country, Length: 2577, dtype: object

# %%
# Task 08b Display only the Country column, using "[]" method.
ramen_data['Country']
# Out:
# 0          Japan
# 1         Taiwan
# 2            USA
# 3         Taiwan
# 4          India
#           ...
# 2572     Vietnam
# 2573    Thailand
# 2574    Thailand
# 2575    Thailand
# 2576         USA
# Name: Country, Length: 2577, dtype: object

# %%
# Task 08c Display only the Country column, using "[[]]" method.
ramen_data[['Country']]
# Out:
#        Country
# 0        Japan
# 1       Taiwan
# 2          USA
# 3       Taiwan
# 4        India
# ...        ...
# 2572   Vietnam
# 2573  Thailand
# 2574  Thailand
# 2575  Thailand
# 2576       USA
#
# [2577 rows x 1 columns]

# %%
# Task 09 Display the data after it has been sorted by the Stars column, from high to low
ramen_data.sort_values('Stars', ascending=False)
# Out:
#                Brand                                            Variety Style  \
# 1585     Prima Taste                            Singapore Laksa La Mian  Pack
# 446         Maruchan  Instant Lunch Chipotle Chicken Flavor Ramen No...   Cup
# 484         Nongshim          Champong Noodle Soup Spicy Seafood Flavor  Pack
# 483           Nissin                              Straits Kitchen Laksa  Pack
# 1613          Nissin                 Raoh Backfat Rich Soy Sauce Flavor  Bowl
# ...              ...                                                ...   ...
# 522             Koyo                 Garlic Pepper Reduced Sodium Ramen  Pack
# 561    Samyang Foods                            Honey & Cheese Big Bowl  Bowl
# 950            Azami                                Kimchee Noodle Soup   Cup
# 2079  Hsin Tung Yang                     Tiny Noodle With Oyster Flavor  Pack
# 52     Uni-President                                    Mushroom Flavor  Pack
#
#           Country  Stars
# ...

# %%
# Task 10 Replace USA with "United States" in Country column. Save changes back to the Data Frame
#  then display the first 5 rows to show the change took place.
ramen_data.Country.replace('USA', 'United States', inplace = True)
ramen_data.head()
# Out:
#             Brand                                            Variety Style  \
# 0       New Touch                          T's Restaurant Tantanmen    Cup
# 1        Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack
# 2          Nissin                      Cup Noodles Chicken Vegetable   Cup
# 3         Wei Lih                      GGE Ramen Snack Tomato Flavor  Pack
# 4  Ching's Secret                                    Singapore Curry  Pack
#
#          Country  Stars
# 0          Japan   3.75
# 1         Taiwan   1.00
# 2  United States   2.25
# 3         Taiwan   2.75
# 4          India   3.75

# %% [markdown]
# # Questions

# %%
# 1 How many countries were represented in the data?
ramen_data.Country.nunique()
# Out:
# 38

# %%
# 2 Which 3 countries have the highest average rating?
ramen_data.groupby('Country').mean().sort_values('Stars', ascending = False).head(3)
# Out:
#              Stars
# Country
# Brazil    4.350000
# Sarawak   4.333333
# Cambodia  4.200000

# %%
# 3 Which 3 countries have the lowest average rating?
ramen_data.groupby('Country').mean().sort_values('Stars').head(3)
# Out:
#                 Stars
# Country
# Nigeria      1.500000
# Canada       2.243902
# Netherlands  2.483333

# %%
# 4 Which 3 countries have the most brands and how many brands does each country have?
ramen_data.groupby('Country').count()[['Brand']].sort_values('Brand', ascending = False).head(3)
# Out:
#              Brand
# Country
# Japan          352
# USA            323
# South Korea    307
