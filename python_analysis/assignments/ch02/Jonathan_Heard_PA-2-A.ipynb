# %% [markdown]
# # Chapter 2, Assignment 2, Avocado analysis
# ## Author: Jonathan Heard
# ## Class: CIS256DA

# %% [markdown]
# Chapter 2 Asignment
#
# Tasks List
#
#  1. Read the data from the CSV file into a DataFrame (2 pts.).
#  2. Display type, memory consumption, and null count information using the info() method (2 pts.).
#  3. Display the number of unique values in each column (2 pts.).
#  4. Display all the rows of data that JupyterLab displays by default (2 pts.).
#  5. Display the first and last five rows of data and the first and last four columns of data (3 pts.).
#  6. Choose any three columns, access them with bracket notation, and display the first five rows of this data (2 pts.).
#  7. Select one column and access it with dot notation (2 pts.).
#  8. Multiply the Total Volume and AveragePrice columns, and store the result in a new column called EstimatedRevenue. Then, display the first five rows of this data to confirm that the column was added and has the correct values (3 pts.).
#  9. Create a DataFrame that’s grouped by region and type and that includes the average price for the grouped columns. Then, reset the index and display the first five rows (4 pts.).
# 10. Create a bar plot that shows the mean, median, and standard deviation of the Total Volume column by year (2 pts.).
#
# Questions
#
# You must show the code that answers each question, include your answer as a comment.
#
# 1. How many unique regions are there (3 pts.)?
# 2. What is the average price for each type of avocado (organic and conventional)? Be sure to include just the type and AveragePrice columns in the results (3 pts.).
# 3. Which region has the lowest average price for organic avocados? Hint: Create wide data from the grouped data that you created in task 8 (3 pts.).
# 4. Have the Total Bags sold per year of each type of avocado become more or less consistent over time (3 pts.)?
#
# After completing the assignment, please submit your .ipynb file.

# %% [markdown]
# ## Import required modules

# %%
import pandas as pd

# %% [markdown]
# # Tasks list

# %%
# Task 01 Read the data from the CSV file into a DataFrame.
avocado_data = pd.read_csv("avocado.csv")

# %%
# Task 02 Display type, memory consumption, and null count information using the info() method.
avocado_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
# Task 02a Display type, memory consumption, and null count information using the info() method.
# Wasn't sure if 'memory_usage' was required, so I supplied both.
avocado_data.info(memory_usage = 'deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 5.0 MB

# %%
# Task 03 Display the number of unique values in each column.
avocado_data.nunique()
# Out:
# Unnamed: 0         53
# Date              169
# AveragePrice      259
# Total Volume    18237
# 4046            17702
# 4225            18103
# 4770            12071
# Total Bags      18097
# Small Bags      17321
# Large Bags      15082
# XLarge Bags      5588
# type                2
# year                4
# region             54
# dtype: int64

# %%
# Task 04. Display all the rows of data that JupyterLab displays by default.
avocado_data
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
# Task 05. Display the first and last five rows of data and the first and last four columns of data.
with pd.option_context(
        'display.max_rows', 10,
        'display.max_columns', 8):
    display(avocado_data)
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume  ...  XLarge Bags  \
# 0               0  2015-12-27          1.33      64236.62  ...          0.0
# 1               1  2015-12-20          1.35      54876.98  ...          0.0
# 2               2  2015-12-13          0.93     118220.22  ...          0.0
# 3               3  2015-12-06          1.08      78992.15  ...          0.0
# 4               4  2015-11-29          1.28      51039.60  ...          0.0
# ...           ...         ...           ...           ...  ...          ...
# 18244           7  2018-02-04          1.63      17074.83  ...          0.0
# 18245           8  2018-01-28          1.71      13888.04  ...          0.0
# 18246           9  2018-01-21          1.87      13766.76  ...          0.0
# 18247          10  2018-01-14          1.93      16205.22  ...          0.0
# 18248          11  2018-01-07          1.62      17489.58  ...          0.0
#
#                type  year            region
# ...

# %%
# Task 06. Choose any three columns, access them with bracket notation, and display the first five rows of this data.
avocado_data[['Date', 'Total Volume', 'region']].head(5)
# Out:
#          Date  Total Volume  region
# 0  2015-12-27      64236.62  Albany
# 1  2015-12-20      54876.98  Albany
# 2  2015-12-13     118220.22  Albany
# 3  2015-12-06      78992.15  Albany
# 4  2015-11-29      51039.60  Albany

# %%
# Task 07. Select one column and access it with dot notation.
avocado_data.region
# Out:
# 0                  Albany
# 1                  Albany
# 2                  Albany
# 3                  Albany
# 4                  Albany
#                ...
# 18244    WestTexNewMexico
# 18245    WestTexNewMexico
# 18246    WestTexNewMexico
# 18247    WestTexNewMexico
# 18248    WestTexNewMexico
# Name: region, Length: 18249, dtype: object

# %%
# Task 08. Multiply the Total Volume and AveragePrice columns, and store the result in a new column called EstimatedRevenue.
#          Then, display the first five rows of this data to confirm that the column was added and has the correct values.
avocado_data['EstimatedRevenue'] = avocado_data['Total Volume'] * avocado_data.AveragePrice
#          Rather than display all 15 columns, I chose to only display the calculation and the 2 fields needed
#             for the calculation and the Date column.
avocado_data[['Date', 'Total Volume', 'AveragePrice', 'EstimatedRevenue']].head(5)
# Out:
#          Date  Total Volume  AveragePrice  EstimatedRevenue
# 0  2015-12-27      64236.62          1.33        85434.7046
# 1  2015-12-20      54876.98          1.35        74083.9230
# 2  2015-12-13     118220.22          0.93       109944.8046
# 3  2015-12-06      78992.15          1.08        85311.5220
# 4  2015-11-29      51039.60          1.28        65330.6880

# %%
# Task 09. Create a DataFrame that’s grouped by region and type and that includes the average price for the grouped columns.
#          Then, reset the index and display the first five rows.

avocado_data_new = avocado_data[['region','type','AveragePrice']].groupby(['region', 'type']).mean().copy()
# One of may trys to get the result, I think I have been asked for.
# avocado_data_new.groupby(['region', 'type']).mean().head()

avocado_data_new.reset_index(inplace = True)
avocado_data_new.head(5)
# Out:
#                 region          type  AveragePrice
# 0               Albany  conventional      1.348757
# 1               Albany       organic      1.773314
# 2              Atlanta  conventional      1.068817
# 3              Atlanta       organic      1.607101
# 4  BaltimoreWashington  conventional      1.344201

# %%
# Task 10. Create a bar plot that shows the mean, median, and standard deviation of the Total Volume column by year.
avocado_data.groupby('year')['Total Volume'].agg(['mean', 'median', 'std']).plot.barh()
# Out:
# <AxesSubplot:ylabel='year'>

# %% [markdown]
# # Questions

# %%
# 1. How many unique regions are there?
print(f'\nThere are {avocado_data.region.nunique()} unique regions in the data.\n')
# Out:
# There are 54 unique regions in the data.

# %%
# 2. What is the average price for each type of avocado (organic and conventional)?
#    Be sure to include just the type and AveragePrice columns in the results.
avocado_data[['type', 'AveragePrice']].groupby('type').mean()
# Out:
#               AveragePrice
# type
# conventional      1.158040
# organic           1.653999

# %%
# The question included the incorrect task, you should have used the grouped data from task 9, see below
# 3. Which region has the lowest average price for organic avocados?
#    Hint: Create wide data from the grouped data that you created in task 8.
avocado_data_wide = avocado_data.query('type == "organic"')[['region', 'type', 'AveragePrice']]

avocado_data_wide.sort_values(['AveragePrice']).head()

# Below are the various things I tired, until I learned/remembered that the 'type' column was 
#   an object, or rather string data. This required that 'organic' had to be in double quotes to
#   extract it.

# Pivot just failed; but left for future reference.
#avocado_data_wide.pivot(
#   index = 'region', columns = 'type',
#   values = 'AveragePrice')

# avocado_data_wide.groupby(['type', 'region']).sort_values('AveragePrice').head(5)

# print(f'New DataFrame\n, {avocado_data_wide}')
# Out:
#                  region     type  AveragePrice
# 15261  CincinnatiDayton  organic          0.44
# 15473           Detroit  organic          0.48
# 15262  CincinnatiDayton  organic          0.49
# 16162         Nashville  organic          0.51
# 15263  CincinnatiDayton  organic          0.51

# %%
avocado_data_new.pivot(index='region', columns='type', values='AveragePrice').sort_values('organic').head(1)
# Out:
# type     conventional   organic
# region
# Houston      0.825089  1.270769

# %%
# 4. Have the Total Bags sold per year of each type of avocado become more or less consistent over time?
# -1 answer: Year over year in the four years that are represented in this dataset shows that for both
#        organic and conventional avocados the standard deviation has increased. With standard
#    deviation measuring the consistency of data, as that number climbs the consistency decreases.
avocado_data.groupby(['year', 'type'])['Total Bags'].agg(['std']).plot.bar()
print(f'\n\tBased on the data available,\n'
      'the Total Bags sold per year has been steadly increasing,\n'
      '\t\tyear over year.\n\n')
# Out:
# 	Based on the data available,
# the Total Bags sold per year has been steadly increasing,
# 		year over year.
